# %% [markdown]
# ## Processed Data From Hive
#
# This is the processed data from Hive

# %%
import pandas as pd

data = pd.read_csv('final_with_headers.csv')
data.head()
# Out:
# C:\Users\Khor Kean Teng\AppData\Local\Temp\ipykernel_8112\2113432523.py:3: DtypeWarning: Columns (0,3,4,17,18) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv('../final_with_headers.csv')
#              vendor_id          pickup_time dropoff_time flag  rate_code  \
# 1  2021-07-01 00:30:52  2021-07-01 00:35:36            N    1         74
# 2  2021-07-01 00:25:36  2021-07-01 01:01:31            N    1        116
# 2  2021-07-01 00:05:58  2021-07-01 00:12:00            N    1         97
# 2  2021-07-01 00:41:40  2021-07-01 00:47:23            N    1         74
# 2  2021-07-01 00:51:32  2021-07-01 00:58:46            N    1         42
#
#    pu_location  do_location passenger_count  trip_distance  fare_amount  \
# 1          168            1             1.2            6.0          0.5
# 2          265            2           13.69           42.0          0.5
# 2           33            1            0.95            6.5          0.5
# ...
